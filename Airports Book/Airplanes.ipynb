# %%
#import dependencies and csv files
import pandas as pd 

airports = pd.read_csv('airports', names=["index", "airport_name", "city", "country", "airport", "idk_id", "lat", "lng",
                                         "altitude", "timezone", "DST", "Tz", "airport_type", "source"])
delays = pd.read_csv('469260606_122019_5347_airline_delay_causes.csv')

# %%
airports.head(2)
# Out:
#    index    airport_name    city           country airport idk_id      lat  \
# 0      1  Goroka Airport  Goroka  Papua New Guinea     GKA   AYGA -6.08169
# 1      2  Madang Airport  Madang  Papua New Guinea     MAG   AYMD -5.20708
#
#           lng  altitude timezone DST                    Tz airport_type  \
# 0  145.391998      5282       10   U  Pacific/Port_Moresby      airport
# 1  145.789001        20       10   U  Pacific/Port_Moresby      airport
#
#         source
# 0  OurAirports
# 1  OurAirports

# %%
delays.head(2)
# Out:
#    year   month carrier             carrier_name airport  \
# 0  2019      12      EV  ExpressJet Airlines LLC     BDL
# 1  2019      12      EV  ExpressJet Airlines LLC     BGR
#
#                           airport_name  arr_flights  arr_del15  carrier_ct  \
# 0  Hartford, CT: Bradley International         14.0        4.0        2.00
# 1     Bangor, ME: Bangor International         34.0       16.0        4.12
#
#     weather_ct  ...  late_aircraft_ct  arr_cancelled  arr_diverted  \
# 0          0.0  ...              2.00            0.0           0.0
# 1          0.0  ...              7.98            2.0           0.0
#
#     arr_delay   carrier_delay  weather_delay  nas_delay  security_delay  \
# 0       114.0            61.0            0.0        0.0             0.0
# 1      1450.0           682.0            0.0      231.0             0.0
#
#    late_aircraft_delay  Unnamed: 21
# 0                 53.0          NaN
# 1                537.0          NaN
#
# [2 rows x 22 columns]

# %%
#clean & drop un-needed columns

airports.dropna()
airports1 = airports[['airport_name','city', 'country','airport', 'lat','lng']]
airports1.head()
# Out:
#                                   airport_name          city  \
# 0                               Goroka Airport        Goroka
# 1                               Madang Airport        Madang
# 2                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3                               Nadzab Airport        Nadzab
# 4  Port Moresby Jacksons International Airport  Port Moresby
#
#             country airport       lat         lng
# 0  Papua New Guinea     GKA -6.081690  145.391998
# 1  Papua New Guinea     MAG -5.207080  145.789001
# 2  Papua New Guinea     HGU -5.826790  144.296005
# 3  Papua New Guinea     LAE -6.569803  146.725977
# 4  Papua New Guinea     POM -9.443380  147.220001

# %%
#clean & drop un-needed columns
delays.dropna()
delays.head()
# Out:
#    year   month carrier             carrier_name airport  \
# 0  2019      12      EV  ExpressJet Airlines LLC     BDL
# 1  2019      12      EV  ExpressJet Airlines LLC     BGR
# 2  2019      12      EV  ExpressJet Airlines LLC     BHM
# 3  2019      12      EV  ExpressJet Airlines LLC     BNA
# 4  2019      12      EV  ExpressJet Airlines LLC     BRO
#
#                                         airport_name  arr_flights  arr_del15  \
# 0                Hartford, CT: Bradley International         14.0        4.0
# 1                   Bangor, ME: Bangor International         34.0       16.0
# 2  Birmingham, AL: Birmingham-Shuttlesworth Inter...         65.0       13.0
# 3             Nashville, TN: Nashville International        120.0       41.0
# 4  Brownsville, TX: Brownsville South Padre Islan...         96.0       17.0
#
#    carrier_ct   weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# ...

# %%
aviation = pd.merge(delays, airports1, on='airport', how='outer')
aviation.head()
# Out:
#      year   month carrier             carrier_name airport  \
# 0  2019.0    12.0      EV  ExpressJet Airlines LLC     BDL
# 1  2019.0    12.0      F9   Frontier Airlines Inc.     BDL
# 2  2019.0    12.0      NK         Spirit Air Lines     BDL
# 3  2019.0    12.0      YV       Mesa Airlines Inc.     BDL
# 4  2019.0    12.0      YX         Republic Airline     BDL
#
#                         airport_name_x  arr_flights  arr_del15  carrier_ct  \
# 0  Hartford, CT: Bradley International         14.0        4.0        2.00
# 1  Hartford, CT: Bradley International         34.0       10.0        3.79
# 2  Hartford, CT: Bradley International        167.0       27.0        5.52
# 3  Hartford, CT: Bradley International        105.0       21.0       12.00
# 4  Hartford, CT: Bradley International         94.0       11.0        0.80
#
#     weather_ct  ...   carrier_delay  weather_delay  nas_delay  security_delay  \
# ...

# %%
aviation.to_csv('aviation_data.csv')
